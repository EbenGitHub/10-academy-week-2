# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlalchemy
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
data = pd.read_csv("../data/xdr_data.csv")

# %%
data.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
# ...

# %%
data.describe()
# Out:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.490100e+05  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.893173e+18     288.611834     288.097653  8.103762e+04  2.148809e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324302e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    122172.000000    122189.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# ...

# %%
# Check for missing data
data.isnull().sum()
# Out:
# Bearer Id                                      991
# Start                                            1
# Start ms                                         1
# End                                              1
# End ms                                           1
# Dur. (ms)                                        1
# IMSI                                           570
# MSISDN/Number                                 1066
# IMEI                                           572
# Last Location Name                            1153
# Avg RTT DL (ms)                              27829
# Avg RTT UL (ms)                              27812
# Avg Bearer TP DL (kbps)                          1
# Avg Bearer TP UL (kbps)                          1
# TCP DL Retrans. Vol (Bytes)                  88146
# TCP UL Retrans. Vol (Bytes)                  96649
# DL TP < 50 Kbps (%)                            754
# 50 Kbps < DL TP < 250 Kbps (%)                 754
# ...

# %%
data['Avg RTT DL (ms)'].skew()
# Out:
# 62.90782807995961

# %%
from scipy.stats import shapiro

# %%
stat, p = shapiro(data['Avg RTT DL (ms)'].dropna())
if p > 0.05:
    print("Avg RTT DL (ms) is normally distributed", p)
else:
    print("Avg RTT DL (ms) is not normally distributed", p)
# Out:
# Avg RTT DL (ms) is not normally distributed 2.1189776770041153e-187
# /opt/miniconda3/envs/10-a/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 122172.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
sns.boxplot(data['Avg RTT DL (ms)'])
plt.title('Boxplot of Avg RTT DL (ms)')
plt.show()

# %%
stat, p = shapiro(data['Avg RTT UL (ms)'].dropna())
if p > 0.05:
    print("Avg RTT UL (ms) is normally distributed", p)
else:
    print("Avg RTT UL (ms) is not normally distributed", p)
# Out:
# Avg RTT UL (ms) is not normally distributed 1.2407118431892299e-185
# /opt/miniconda3/envs/10-a/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 122189.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
sns.boxplot(data['Avg RTT UL (ms)'])
plt.title('Boxplot of Avg RTT UL (ms)')
plt.show()

# %%
# Data Treatment
# Use mean for normally distributed data, and use median for skewed data (not normally distributed)
data['Avg RTT UL (ms)'] = data['Avg RTT UL (ms)'].fillna(data['Avg RTT UL (ms)'].median())
data['Avg RTT DL (ms)'] = data['Avg RTT DL (ms)'].fillna(data['Avg RTT DL (ms)'].median())

# %%
data[['Avg RTT DL (ms)', 'Avg RTT UL (ms)']].isnull().sum()
# Out:
# Avg RTT DL (ms)    0
# Avg RTT UL (ms)    0
# dtype: int64

# %%
# Plot Avg RTT DL (ms)
sns.histplot(data['Avg RTT DL (ms)'], kde=True, bins=30)
plt.title('Histogram of Avg RTT DL (ms)')
plt.show()

# Plot Avg RTT UL (ms)
sns.histplot(data['Avg RTT UL (ms)'], kde=True, bins=30)
plt.title('Histogram of Avg RTT UL (ms)')
plt.show()

# %%
data['Handset Manufacturer'].isnull().sum()

data['Handset Manufacturer'] = data['Handset Manufacturer'].fillna(data['Handset Manufacturer'].mode()[0])

data['Handset Manufacturer'].isnull().sum()
# Out:
# 0

# %%
data = data.dropna(subset=['MSISDN/Number'])
data.drop(['Nb of sec with 37500B < Vol UL'], axis=1, inplace=True)

# %%
data['Total UL (Bytes)'] = data['HTTP UL (Bytes)'].fillna(0) + data['Youtube UL (Bytes)'].fillna(0)

# %%
data.describe()
# Out:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.485060e+05  148935.000000  148935.000000  1.489350e+05  1.489350e+05
# mean   1.014676e+19     499.246732     498.675442  1.048702e+05  2.082016e+14
# std    2.893262e+18     288.555630     288.089136  8.106343e+04  1.522166e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.788350e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.327000e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.082522e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.489350e+05    148935.000000    148935.000000
# mean    4.188282e+10  4.849493e+13        96.489522        15.293235
# ...

# %%
data.isnull().sum()
# Out:
# Bearer Id                                      429
# Start                                            0
# Start ms                                         0
# End                                              0
# End ms                                           0
# Dur. (ms)                                        0
# IMSI                                             0
# MSISDN/Number                                    0
# IMEI                                             0
# Last Location Name                             589
# Avg RTT DL (ms)                                  0
# Avg RTT UL (ms)                                  0
# Avg Bearer TP DL (kbps)                          0
# Avg Bearer TP UL (kbps)                          0
# TCP DL Retrans. Vol (Bytes)                  87796
# TCP UL Retrans. Vol (Bytes)                  96192
# DL TP < 50 Kbps (%)                            720
# 50 Kbps < DL TP < 250 Kbps (%)                 720
# ...

# %%
data.drop([
    'Nb of sec with 125000B < Vol DL', 
    'Nb of sec with 1250B < Vol UL < 6250B', 
    'Nb of sec with 31250B < Vol DL < 125000B', 
    'Nb of sec with 6250B < Vol DL < 31250B', 
    'Nb of sec with 6250B < Vol UL < 37500B', 
    'Nb of sec with Vol DL < 6250B', 
    'Nb of sec with Vol UL < 1250B'
], axis=1, inplace=True)

# %%
data = data[data['Bearer Id'].notnull()]

# %%
data.isnull().sum()
# Out:
# Bearer Id                             0
# Start                                 0
# Start ms                              0
# End                                   0
# End ms                                0
# Dur. (ms)                             0
# IMSI                                  0
# MSISDN/Number                         0
# IMEI                                  0
# Last Location Name                  160
# Avg RTT DL (ms)                       0
# Avg RTT UL (ms)                       0
# Avg Bearer TP DL (kbps)               0
# Avg Bearer TP UL (kbps)               0
# TCP DL Retrans. Vol (Bytes)       87764
# TCP UL Retrans. Vol (Bytes)       96128
# DL TP < 50 Kbps (%)                 712
# 50 Kbps < DL TP < 250 Kbps (%)      712
# 250 Kbps < DL TP < 1 Mbps (%)       712
# DL TP > 1 Mbps (%)                  712
# UL TP < 10 Kbps (%)                 767
# 10 Kbps < UL TP < 50 Kbps (%)       767
# 50 Kbps < UL TP < 300 Kbps (%)      767
# ...

# %%
data['Last Location Name'] = data['Last Location Name'].fillna('Unknown')

# %%
data['TCP DL Retrans. Vol (Bytes)'] = data['TCP DL Retrans. Vol (Bytes)'].fillna(0)
data['TCP UL Retrans. Vol (Bytes)'] = data['TCP UL Retrans. Vol (Bytes)'].fillna(0)

# %%
data['HTTP DL (Bytes)'] = data['HTTP DL (Bytes)'].fillna(0)
data['HTTP UL (Bytes)'] = data['HTTP UL (Bytes)'].fillna(0)

# %%
data.isnull().sum()
# Out:
# Bearer Id                           0
# Start                               0
# Start ms                            0
# End                                 0
# End ms                              0
# Dur. (ms)                           0
# IMSI                                0
# MSISDN/Number                       0
# IMEI                                0
# Last Location Name                  0
# Avg RTT DL (ms)                     0
# Avg RTT UL (ms)                     0
# Avg Bearer TP DL (kbps)             0
# Avg Bearer TP UL (kbps)             0
# TCP DL Retrans. Vol (Bytes)         0
# TCP UL Retrans. Vol (Bytes)         0
# DL TP < 50 Kbps (%)               712
# 50 Kbps < DL TP < 250 Kbps (%)    712
# 250 Kbps < DL TP < 1 Mbps (%)     712
# DL TP > 1 Mbps (%)                712
# UL TP < 10 Kbps (%)               767
# 10 Kbps < UL TP < 50 Kbps (%)     767
# 50 Kbps < UL TP < 300 Kbps (%)    767
# UL TP > 300 Kbps (%)              767
# HTTP DL (Bytes)                     0
# ...

# %%
# Task 1

# Top 10 Handsets
top_10_handsets = data['Handset Type'].value_counts().head(10)
print("Top 10 Handsets:")
print(top_10_handsets)
# Out:
# Top 10 Handsets:
# Handset Type
# Huawei B528S-23A                19727
# Apple iPhone 6S (A1688)          9395
# Apple iPhone 6 (A1586)           8993
# undefined                        8904
# Apple iPhone 7 (A1778)           6279
# Apple iPhone Se (A1723)          5165
# Apple iPhone 8 (A1905)           4977
# Apple iPhone Xr (A2105)          4556
# Samsung Galaxy S8 (Sm-G950F)     4464
# Apple iPhone X (A1901)           3806
# Name: count, dtype: int64

# %%
# Top 3 Manufacturers
top_3_manufacturers = data['Handset Manufacturer'].value_counts().head(3)
print("Top 3 Handset Manufacturers:")
print(top_3_manufacturers)
# Out:
# Top 3 Handset Manufacturers:
# Handset Manufacturer
# Apple      59339
# Samsung    40429
# Huawei     34296
# Name: count, dtype: int64

# %%
# Top 5 Handsets for Each Top Manufacturer
for manufacturer in top_3_manufacturers.index:
    top_handsets = data[data['Handset Manufacturer'] == manufacturer]['Handset Type'].value_counts().head(5)
    print(f"Top 5 handsets for {manufacturer}:")
    print(top_handsets)
    print()
# Out:
# Top 5 handsets for Apple:
# Handset Type
# Apple iPhone 6S (A1688)    9395
# Apple iPhone 6 (A1586)     8993
# Apple iPhone 7 (A1778)     6279
# Apple iPhone Se (A1723)    5165
# Apple iPhone 8 (A1905)     4977
# Name: count, dtype: int64
#
# Top 5 handsets for Samsung:
# Handset Type
# Samsung Galaxy S8 (Sm-G950F)    4464
# Samsung Galaxy A5 Sm-A520F      3700
# Samsung Galaxy J5 (Sm-J530)     3675
# Samsung Galaxy J3 (Sm-J330)     3456
# Samsung Galaxy S7 (Sm-G930X)    3171
# Name: count, dtype: int64
#
# Top 5 handsets for Huawei:
# Handset Type
# Huawei B528S-23A                  19727
# Huawei E5180                       2074
# Huawei P20 Lite Huawei Nova 3E     2012
# Huawei P20                         1475
# Huawei Y6 2018                      996
# Name: count, dtype: int64

# %%
# Bar Chart for Top 10 Handsets
top_10_handsets.plot(kind='bar', figsize=(10, 6))
plt.title('Top 10 Handsets Used by Customers')
plt.xlabel('Handset Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Bar Chart for Top 3 Manufacturers
top_3_manufacturers.plot(kind='bar', figsize=(8, 5))
plt.title('Top 3 Handset Manufacturers')
plt.xlabel('Manufacturer')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# Interpretation
#
# 1. Top 10 Handsets:
#
# - Huawei B528S-23A leads with 19,727 users.
# - Apple dominates with 7 models, including the iPhone 6S and iPhone 6, showing strong brand loyalty.
# - Samsung Galaxy S8 is the only Samsung model in the top 10.
# - "undefined" indicates incomplete or missing data.
#
# 2. Top 3 Manufacturers:
#
# - Apple leads (59,339 users), followed by Samsung (40,429) and Huawei (34,296).
# - Apple and Samsung appeal across segments, while Huawei’s dominance in budget models like B528S-23A is notable.
#
# Recommendations
#
# 1. Marketing:
#
# - Target iPhone 6 and 6S users with upgrade offers.
# - Promote Huawei’s budget models and Samsung’s mid-range devices (e.g., Galaxy A5, J5).
# - Investigate "undefined" devices to improve data quality.
#
# 2. Strategic Growth:
#
# - Collaborate with Apple, Samsung, and Huawei for exclusive plans.
# - Optimize network performance for top devices like Huawei B528S-23A and iPhone 6S.
#
# 3. User Retention:
#
# - Launch trade-in programs for older handsets.
# - Focus on device-specific customer support and network optimization.

# %%
# Task 2

# Aggregate metrics per customer
engagement_metrics = data.groupby('MSISDN/Number').agg({
    'Dur. (ms)': 'sum',  # Total session duration
    'HTTP DL (Bytes)': 'sum',  # Total download data
    'HTTP UL (Bytes)': 'sum',  # Total upload data
})

# Calculate total traffic (Download + Upload)
engagement_metrics['Total Traffic (Bytes)'] = engagement_metrics['HTTP DL (Bytes)'] + engagement_metrics['HTTP UL (Bytes)']

# Add session frequency
engagement_metrics['Session Frequency'] = data['MSISDN/Number'].value_counts()

# Rename columns for clarity
engagement_metrics.rename(columns={
    'Dur. (ms)': 'Total Duration (ms)',
    'HTTP DL (Bytes)': 'Total Download (Bytes)',
    'HTTP UL (Bytes)': 'Total Upload (Bytes)',
}, inplace=True)

engagement_metrics.head()
# Out:
#                Total Duration (ms)  Total Download (Bytes)  \
# MSISDN/Number
# 3.360100e+10              116720.0                     0.0
# 3.360100e+10              181230.0                     0.0
# 3.360100e+10              134969.0                     0.0
# 3.360101e+10               49878.0                  8749.0
# 3.360101e+10               37104.0             185208098.0
#
#                Total Upload (Bytes)  Total Traffic (Bytes)  Session Frequency
# MSISDN/Number
# 3.360100e+10                    0.0                    0.0                  1
# 3.360100e+10                    0.0                    0.0                  1
# 3.360100e+10                    0.0                    0.0                  1
# 3.360101e+10                  653.0                 9402.0                  1
# 3.360101e+10              4733818.0            189941916.0                  2

# %%
# Top 10 customers by each metric
top_customers_duration = engagement_metrics.nlargest(10, 'Total Duration (ms)')
top_customers_download = engagement_metrics.nlargest(10, 'Total Download (Bytes)')
top_customers_upload = engagement_metrics.nlargest(10, 'Total Upload (Bytes)')
top_customers_traffic = engagement_metrics.nlargest(10, 'Total Traffic (Bytes)')

print("Top 10 Customers by Total Duration:")
print(top_customers_duration)
print("Top 10 Customers by Total Traffic:")
print(top_customers_traffic)
# Out:
# Top 10 Customers by Total Duration:
#                Total Duration (ms)  Total Download (Bytes)  \
# MSISDN/Number
# 3.362578e+10            18553754.0            1.957540e+05
# 3.361489e+10             9966898.0            7.019594e+07
# 3.376054e+10             9279434.0            3.286280e+07
# 3.362632e+10             8791927.0            1.720802e+06
# 3.366716e+10             8744914.0            2.524831e+07
# 3.366284e+10             6614270.0            2.275949e+09
# 3.366469e+10             6288730.0            0.000000e+00
# 3.360313e+10             6287761.0            1.070111e+07
# 3.366746e+10             5649882.0            0.000000e+00
# 3.376041e+10             5321667.0            5.433763e+07
#
#                Total Upload (Bytes)  Total Traffic (Bytes)  Session Frequency
# MSISDN/Number
# 3.362578e+10                67482.0           2.632360e+05                 17
# 3.361489e+10              4999215.0           7.519515e+07                 17
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Select relevant columns for clustering
clustering_data = engagement_metrics[['Total Duration (ms)', 'Total Traffic (Bytes)', 'Session Frequency']]

# Normalize data
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(clustering_data)

print("Normalized Data:")
print(normalized_data[:5])
# Out:
# Normalized Data:
# [[5.90824890e-03 0.00000000e+00 0.00000000e+00]
#  [9.38651221e-03 0.00000000e+00 0.00000000e+00]
#  [6.89220220e-03 0.00000000e+00 0.00000000e+00]
#  [2.30424834e-03 1.28758030e-07 0.00000000e+00]
#  [1.61549721e-03 2.60120687e-03 5.88235294e-02]]

# %%
from sklearn.cluster import KMeans

# Elbow method to find optimal k
inertia = []
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, random_state=42).fit(normalized_data)
    inertia.append(kmeans.inertia_)

# Plot the elbow curve
plt.plot(range(1, 10), inertia, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# K-Means Clustering (k=3)
kmeans = KMeans(n_clusters=3, random_state=42)
engagement_metrics['Cluster'] = kmeans.fit_predict(normalized_data)

print("Engagement Clusters:")
print(engagement_metrics['Cluster'].value_counts())
# Out:
# Engagement Clusters:
# Cluster
# 2    77384
# 0    25833
# 1     3254
# Name: count, dtype: int64

# %%
# Visualize clusters using pairplot
engagement_metrics['Cluster'] = engagement_metrics['Cluster'].astype(str)  # Convert to categorical
sns.pairplot(engagement_metrics, hue='Cluster', diag_kind='kde', palette='Set2')
plt.show()

# %%
cluster_stats = engagement_metrics.groupby('Cluster').mean()
print("Cluster Statistics:")
print(cluster_stats)

# %%
# Task 3
# Aggregate metrics per customer
experience_metrics = data.groupby('MSISDN/Number').agg({
    'TCP DL Retrans. Vol (Bytes)': 'mean',  # Average TCP retransmission
    'Avg RTT DL (ms)': 'mean',  # Average Round Trip Time (RTT)
    'Avg Bearer TP DL (kbps)': 'mean',  # Average throughput
    'Handset Type': 'first',  # Handset type
}).reset_index()

# Rename columns for clarity
experience_metrics.rename(columns={
    'TCP DL Retrans. Vol (Bytes)': 'Avg TCP Retrans (Bytes)',
    'Avg RTT DL (ms)': 'Avg RTT (ms)',
    'Avg Bearer TP DL (kbps)': 'Avg Throughput (kbps)'
}, inplace=True)

experience_metrics.head()
# Out:
#    MSISDN/Number  Avg TCP Retrans (Bytes)  Avg RTT (ms)  \
# 0   3.360100e+10                      0.0          46.0
# 1   3.360100e+10                      0.0          30.0
# 2   3.360100e+10                      0.0          45.0
# 3   3.360101e+10                   1066.0          69.0
# 4   3.360101e+10                4674815.0          57.0
#
#    Avg Throughput (kbps)                    Handset Type
# 0                   37.0  Huawei P20 Lite Huawei Nova 3E
# 1                   48.0          Apple iPhone 7 (A1778)
# 2                   48.0                       undefined
# 3                  204.0         Apple iPhone 5S (A1457)
# 4                20197.5         Apple iPhone Se (A1723)

# %%
# Top 10 values
top_tcp_retrans = experience_metrics.nlargest(10, 'Avg TCP Retrans (Bytes)')
top_rtt = experience_metrics.nlargest(10, 'Avg RTT (ms)')
top_throughput = experience_metrics.nlargest(10, 'Avg Throughput (kbps)')

# Bottom 10 values
bottom_tcp_retrans = experience_metrics.nsmallest(10, 'Avg TCP Retrans (Bytes)')
bottom_rtt = experience_metrics.nsmallest(10, 'Avg RTT (ms)')
bottom_throughput = experience_metrics.nsmallest(10, 'Avg Throughput (kbps)')

# Most frequent values
most_freq_tcp_retrans = experience_metrics['Avg TCP Retrans (Bytes)'].mode()
most_freq_rtt = experience_metrics['Avg RTT (ms)'].mode()
most_freq_throughput = experience_metrics['Avg Throughput (kbps)'].mode()

# %%
# Distribution of Average Throughput per Handset Type
sns.boxplot(x='Handset Type', y='Avg Throughput (kbps)', data=experience_metrics)
plt.title('Distribution of Average Throughput per Handset Type')
plt.xticks(rotation=45)
plt.show()

# Distribution of Average TCP Retransmission per Handset Type
sns.boxplot(x='Handset Type', y='Avg TCP Retrans (Bytes)', data=experience_metrics)
plt.title('Distribution of Average TCP Retransmission per Handset Type')
plt.xticks(rotation=45)
plt.show()

# %%
# Normalize the data
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(experience_metrics[['Avg TCP Retrans (Bytes)', 'Avg RTT (ms)', 'Avg Throughput (kbps)']])

# K-Means Clustering (k=3)
kmeans = KMeans(n_clusters=3, random_state=42)
experience_metrics['Cluster'] = kmeans.fit_predict(normalized_data)

# Visualize Clusters
sns.pairplot(experience_metrics, hue='Cluster', diag_kind='kde', palette='Set2')
plt.title('User Experience Clusters')
plt.show()

# %% [markdown]
# Insights
# 1. Cluster 0 (Low-Experience Group):
#
# - This group shows high average RTT (latency) and low throughput, indicating poor network performance.
# - Customers in this cluster likely experience frequent delays or slow data transfer.
#
# 2. Cluster 1 (Moderate-Experience Group):
#
# - This group has a balanced performance with moderate RTT and throughput.
# - These users likely experience satisfactory service but have room for improvement.
#
# 3. Cluster 2 (High-Experience Group):
#
# - This cluster has low RTT and high throughput, indicating excellent network performance.
# - These users are likely satisfied with their experience and represent your most loyal and high-value customers.
#
# 4. TCP Retransmission:
#
# - All clusters show similar distributions of average TCP retransmissions, meaning retransmissions may not be a significant differentiator for user experience.
#
# Recommendations
# 1. Focus on Cluster 0 (Low-Experience Group):
# - Improve Network Performance:
#     - Investigate and resolve high latency issues for this group.
#     - Optimize network coverage and capacity in areas where these users are located.
# - Customer Outreach:
#     - Provide targeted support to address specific issues (e.g., network troubleshooting).
#     - Offer incentives or free trials of premium services to encourage engagement.
# 2. Engage Cluster 1 (Moderate-Experience Group):
# - Upsell Opportunities:
#     - Target these users with promotions for premium plans or devices.
# - Performance Optimization:
#     - Ensure consistent service quality to prevent churn.
#     - Monitor metrics to identify and address any emerging issues.
# 3. Retain Cluster 2 (High-Experience Group):
# - Reward Loyalty:
#     - Provide exclusive benefits or loyalty rewards to maintain satisfaction and engagement.
# - Monitor for Outliers:
#     - Continuously monitor performance to prevent any degradation of experience for these users.
# 4. General Strategy:
# - Optimize Handset-Specific Performance:
#     - Analyze handset types across clusters to identify devices prone to performance issues (e.g., older models or specific manufacturers).
# - Network-Wide Improvements:
#     - Focus on reducing RTT and increasing throughput across all clusters to improve overall user satisfaction.
